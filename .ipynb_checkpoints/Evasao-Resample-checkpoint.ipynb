# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Ler dados

# %%
# Acao Extensiva

df = pd.read_csv("data/AE_GO_RO.csv", low_memory=False)
df2 = pd.read_csv("data/AE_MS_SE.csv", low_memory=False)
df3 = pd.read_csv("data/AE_('ES','MA','PB', 'PE', 'RO', 'RR','SE', 'SG','TO', 'PI').csv", low_memory=False)
df = df.loc[df.DR=="RO"]

df = pd.concat([df, df2, df3])


df.drop_duplicates(inplace=True)

# Cursos
df_curso = pd.read_csv("data/Curso_GO_RO.csv")
df_curso2 = pd.read_csv("data/Curso_MS_SE.csv")
df_curso3 = pd.read_csv("data/Curso_('ES','MA','PB', 'PE', 'RO', 'RR','SE', 'SG','TO', 'PI').csv")
df_curso = pd.concat([df_curso, df_curso2, df_curso3])

df_curso.drop_duplicates(inplace=True)
# Uops

df_uop = pd.read_csv("data/UOP.csv")

df = df.merge(df_uop[["Codigo_Unidade", "codigo_ibge"]], left_on="Cod_Unidade",
             right_on="Codigo_Unidade", how="left")

for col in "Data_Nascimento", 'Data_Matricula', 'Data_Status_Matricula', 'Data_Inicio', 'Data_Fim': 
    df[col] = pd.to_datetime(df[col])

# %% [markdown]
# ### Features Engineering

# %%
# Aluno matriculado em mais de um curso?

mat_alunos = df.groupby(["Doc_Identificacao"]).nunique()["Cod_Curso_Senac"].reset_index()
mat_alunos.loc[mat_alunos["Cod_Curso_Senac"]>1, "multicurso"] = 1
mat_alunos.fillna(0, inplace=True)
#mat_alunos.sort_values("Cod_Curso_Senac", ascending=False)
df = df.merge(mat_alunos[["Doc_Identificacao", "multicurso"]], 
              on="Doc_Identificacao", how="left")

# Aluno matriculado no mesmo municipio da unidade

df.loc[df.Municipio_Residencia_Aluno==df.codigo_ibge ,"mesmomuni"] = 1
df['mesmomuni'].fillna(0, inplace=True)

# %% [markdown]
# ### Criação de bins

# %%
df.dropna(subset=["Data_Nascimento"], inplace=True)

df["idade"] = np.round((datetime.now() - df["Data_Nascimento"])/np.timedelta64(1,"Y")).astype("int")
df = df.loc[df.idade<100]

df['bins_idade'] = pd.cut(x=df['idade'], bins=[0,14, 20, 25, 30,
                                          40, 50, 60, 100], 
                         labels=[0, 1,2,3,4,5,6,7])

df['bins_CH'] = pd.cut(x=df['Carga_Horaria_Turma'], bins=[-1, 0, 30, 100, 6000], 
                         labels=[0,1,2,3])
df['bins_CHE'] = pd.cut(x=df['Carga_Horaria_Estagio_Turma'], bins=[-1, 0, 200, 700, 3000], 
                         labels=[0, 1,2,3])

df['bins_CHE'].fillna(0, inplace=True)
df['bins_CHE'] = df['bins_CHE'].astype(int)
df['bins_CH'].fillna(0, inplace=True)
df['bins_CH'] = df['bins_CH'].astype(int)
df = df.loc[~df["idade"]<100]
df['bins_idade'] = df['bins_idade'].astype(int)

df.drop(['idade', 'Carga_Horaria_Turma','Carga_Horaria_Estagio_Turma'], axis=1, inplace=True)

# %% [markdown]
# ### Coluna Evadido (target)

# %%
df.loc[df.Cod_Esp_Matricula==3, "evadido"] = 1
df["evadido"].fillna(0, inplace=True)

# %% [markdown]
# ## EDA

# %%
df.groupby("evadido")["Matricula_Apurada_Mes"].sum().plot(kind="bar", 
                                                          title="Evadidos",
                                                         figsize=(3,2))
plt.show()
df.loc[df.evadido==1].groupby("Status_Turma_Senac")["Matricula_Apurada_Mes"].\
sum().plot(kind="bar",title="Status Turma",figsize=(3,2))
plt.show()

df.loc[df.evadido==1].groupby("Cod_Mod_Recurso")["Matricula_Apurada_Mes"].sum().plot(kind="bar",
                                                                            title="Recurso",
                                                                             figsize=(3,2))
plt.show()

df.loc[df.evadido==1].groupby("multicurso")["Matricula_Apurada_Mes"].sum().plot(kind="bar",
                                                                            title="Multiplos cursos",
                                                                             figsize=(3,2))


plt.show()

df.loc[df.evadido==1].groupby("mesmomuni")["Matricula_Apurada_Mes"].sum().plot(kind="bar",
                                                                           title="Mesmo Muni",
                                                                           figsize=(3,2))
# Out:
# <AxesSubplot:title={'center':'Mesmo Muni'}, xlabel='mesmomuni'>

# %%
df = df.loc[df.Status_Turma_Senac==2]

# %% [markdown]
# ### Merge com cursos

# %%
df = df[["DR", 'Cod_Curso_Senac', 'Tipo_Ensino',
         'Cod_Mod_Recurso', 'Cod_Origem', 'Cod_Nacionalidade','Atestado_Baixa_Renda', 'Sexo', 'Cod_Raca', 'Cod_Escolaridade',
           'Cod_Estado_Civil',  'Deficiencia', 'Trabalha_Atualmente', 'Cod_Renda_Familiar', 'Contrato_Aprendizagem',
           'CursoId', "bins_idade", "bins_CH", "bins_CHE", 'multicurso','mesmomuni','evadido']]

df_curso = df_curso[["Id_Curso", 'Id_Eixo', 'Id_Modalidade', 'Id_TipoCurso','Regional']].drop_duplicates()
df_curso["Regional"] = df_curso["Regional"].str.strip()

df = df.merge(df_curso, left_on=["DR",  'Cod_Curso_Senac'],
             right_on=["Regional", "Id_Curso"], how="left")

df.drop(["DR", "Regional", "Id_Curso", "Cod_Curso_Senac"], axis=1, inplace=True)

# %%
print(len(df))
print(df.isna().sum())
print("---------")
print("% evadido",len(df.loc[df.evadido==1])/len(df))
df.groupby("evadido")["Tipo_Ensino"].count().plot(kind="bar", 
                                                title="Evadidos turmas concluidas",
                                                figsize=(3,2))
# Out:
# 203034
# Tipo_Ensino                   0
# Cod_Mod_Recurso               0
# Cod_Origem                38065
# Cod_Nacionalidade             0
# Atestado_Baixa_Renda          0
# Sexo                          0
# Cod_Raca                  41772
# Cod_Escolaridade          15460
# Cod_Estado_Civil          39714
# Deficiencia                   0
# Trabalha_Atualmente      116040
# Cod_Renda_Familiar       118085
# Contrato_Aprendizagem      5114
# CursoId                       0
# bins_idade                    0
# bins_CH                       0
# bins_CHE                      0
# multicurso                    0
# mesmomuni                     0
# evadido                       0
# Id_Eixo                       0
# Id_Modalidade                 0
# Id_TipoCurso                  0
# dtype: int64
# ---------
# % evadido 0.1263138193603042
# <AxesSubplot:title={'center':'Evadidos turmas concluidas'}, xlabel='evadido'>

# %% [markdown]
# ### Correlation

# %%
corr = df.corr()

# %%
cmap = sns.diverging_palette(500, 10, as_cmap=True)
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
            cmap=cmap, center=0)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

df = df[['Tipo_Ensino', 'Cod_Mod_Recurso', 'Sexo', 'Cod_Raca',
         'Cod_Escolaridade', 'Cod_Estado_Civil', 'Deficiencia',
         'Trabalha_Atualmente', 'Cod_Renda_Familiar', 'Contrato_Aprendizagem',
         'bins_idade', 'bins_CH', 'bins_CHE', 'Id_Eixo',
         'Id_TipoCurso', "multicurso", "mesmomuni","evadido"]]

for c in df.columns:
    fig, ax = plt.subplots(figsize=(3,2))
    sns.heatmap(pd.crosstab(df[c],df.evadido, normalize='index'), annot=True, fmt="2f", ax=ax)
    plt.title(c)
    plt.show()

# %% [markdown]
# ### Onehot

# %%
print(len(df))
df = df.dropna()
print(len(df))
# Out:
# 203034
# 76481

# %%
df_dum = pd.get_dummies(df, prefix=[c for c in df.columns[:-1]], 
                        columns = [c for c in df.columns[:-1]], 
                        drop_first=False)

# %%
print(len(df_dum.columns))
df_dum.columns
# Out:
# 81
# Index(['evadido', 'Tipo_Ensino_1.0', 'Tipo_Ensino_5.0', 'Tipo_Ensino_6.0',
#        'Tipo_Ensino_7.0', 'Cod_Mod_Recurso_1.0', 'Cod_Mod_Recurso_2.0',
#        'Cod_Mod_Recurso_3.0', 'Sexo_1.0', 'Sexo_2.0', 'Cod_Raca_1.0',
#        'Cod_Raca_2.0', 'Cod_Raca_3.0', 'Cod_Raca_4.0', 'Cod_Raca_5.0',
#        'Cod_Raca_6.0', 'Cod_Escolaridade_1.0', 'Cod_Escolaridade_2.0',
#        'Cod_Escolaridade_3.0', 'Cod_Escolaridade_4.0', 'Cod_Escolaridade_5.0',
#        'Cod_Escolaridade_6.0', 'Cod_Escolaridade_7.0', 'Cod_Escolaridade_8.0',
#        'Cod_Escolaridade_9.0', 'Cod_Escolaridade_10.0', 'Cod_Estado_Civil_1.0',
#        'Cod_Estado_Civil_2.0', 'Cod_Estado_Civil_3.0', 'Cod_Estado_Civil_4.0',
#        'Cod_Estado_Civil_5.0', 'Deficiencia_0.0', 'Deficiencia_1.0',
#        'Trabalha_Atualmente_0.0', 'Trabalha_Atualmente_1.0',
#        'Cod_Renda_Familiar_1.0', 'Cod_Renda_Familiar_2.0',
#        'Cod_Renda_Familiar_3.0', 'Cod_Renda_Familiar_4.0',
#        'Cod_Renda_Familiar_5.0', 'Cod_Renda_Familiar_6.0',
#        'Cod_Renda_Familiar_7.0', 'Cod_Renda_Familiar_8.0',
#        'Contrato_Aprendizagem_0.0', 'Contrato_Aprendizagem_1.0',
#        'bins_idade_0', 'bins_idade_1', 'bins_idade_2', 'bins_idade_3',
#        'bins_idade_4', 'bins_idade_5', 'bins_idade_6', 'bins_idade_7',
#        'bins_CH_1', 'bins_CH_2', 'bins_CH_3', 'bins_CHE_0', 'bins_CHE_1',
#        'bins_CHE_2', 'bins_CHE_3', 'Id_Eixo_1', 'Id_Eixo_2', 'Id_Eixo_3',
#        'Id_Eixo_4', 'Id_Eixo_5', 'Id_Eixo_6', 'Id_Eixo_7', 'Id_Eixo_10',
#        'Id_Eixo_11', 'Id_TipoCurso_1', 'Id_TipoCurso_2', 'Id_TipoCurso_3',
#        'Id_TipoCurso_4', 'Id_TipoCurso_5', 'Id_TipoCurso_6', 'Id_TipoCurso_8',
#        'Id_TipoCurso_9', 'multicurso_0.0', 'multicurso_1.0', 'mesmomuni_0.0',
#        'mesmomuni_1.0'],
#       dtype='object')

# %% [markdown]
# ## ML

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif, mutual_info_classif

# %%
_df = df_dum.dropna()

X = _df[[c for c in _df.columns[1:]]]
y = _df.evadido
print("% evadidos = ", (y[y==1].sum())/len(y))
# Out:
# % evadidos =  0.178436474418483

# %%
_df["evadido"].value_counts()
# Out:
# 0.0    62834
# 1.0    13647
# Name: evadido, dtype: int64

# %% [markdown]
# ## Resample

# %% [markdown]
# ### Upsampling

# %%
from sklearn.utils import resample

#create two different dataframe of majority and minority class 
df_majority = _df[(_df['evadido']==0)] 
df_minority = _df[(_df['evadido']==1)] 
# upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,    # sample with replacement
                                 n_samples= 62834, # to match majority class
                                 random_state=42)  # reproducible results
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_minority_upsampled, df_majority])

# %%
df_upsampled["evadido"].value_counts()
# Out:
# 1.0    62834
# 0.0    62834
# Name: evadido, dtype: int64

# %%
_df = df_upsampled.dropna()
X = _df[[c for c in _df.columns[1:]]]
y = _df.evadido
print("% evadidos = ", (y[y==1].sum())/len(y))
# Out:
# % evadidos =  0.5

# %% [markdown]
# #### Melhores variaveis com chi_square

# %%
f = 77
bestfeatures = SelectKBest(score_func=chi2, k=f)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score_chi']  #naming the dataframe columns

# %%
featureScores.sort_values("Score_chi", ascending=False)
# Out:
#                    Specs    Score_chi
# 74        Id_TipoCurso_8  3076.745941
# 53             bins_CH_2  3047.384033
# 70        Id_TipoCurso_3  2830.448785
# 5    Cod_Mod_Recurso_2.0  2250.577277
# 52             bins_CH_1  2089.781641
# ..                   ...          ...
# 28  Cod_Estado_Civil_4.0     1.029315
# 30       Deficiencia_0.0     0.666014
# 55            bins_CHE_0     0.478768
# 23  Cod_Escolaridade_9.0     0.220480
# 13          Cod_Raca_5.0     0.091050
#
# [80 rows x 2 columns]

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(0.2)
sel.fit(X,y)
# Out:
# VarianceThreshold(threshold=0.2)

# %%
_X = pd.DataFrame({"feature":sel.feature_names_in_,"variancia":sel.variances_}).sort_values("variancia", 
                                                                                            ascending=False)
_X
# Out:
#                    feature  variancia
# 35  Cod_Renda_Familiar_2.0   0.247283
# 61               Id_Eixo_3   0.242194
# 0          Tipo_Ensino_1.0   0.239616
# 2          Tipo_Ensino_6.0   0.237340
# 12            Cod_Raca_4.0   0.229534
# ..                     ...        ...
# 27    Cod_Estado_Civil_3.0   0.001351
# 39  Cod_Renda_Familiar_6.0   0.001224
# 75          Id_TipoCurso_9   0.001168
# 58              bins_CHE_3   0.000938
# 44            bins_idade_0   0.000382
#
# [80 rows x 2 columns]

# %%
selected_X = _X.loc[_X.variancia>=0.2]['feature'].values

# %% [markdown]
# ### Comparação de modelos default

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# X_ = X[selected_X]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
model_pipeline = []
model_pipeline.append(LogisticRegression())
model_pipeline.append(SVC(probability=True))
model_pipeline.append(KNeighborsClassifier())
model_pipeline.append(DecisionTreeClassifier())
model_pipeline.append(RandomForestClassifier())
model_pipeline.append(GaussianNB())

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
model_list = ["Logistic Regression", "SVM", "KNN", 
              "Decision Tree", "Random Forest", "Naive Bayes"]
acc_list = []
auc_list = []
cm_list =[]
auc_rc_list= []

for model in model_pipeline:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)
    acc_list.append(metrics.accuracy_score(y_test, y_pred))
    fpr, tpr, _thresholds = metrics.roc_curve(y_test, y_pred)
    auc_list.append(round(metrics.auc(fpr, tpr), 2))
    cm_list.append(confusion_matrix(y_test, y_pred))
    pr, rc, _threshold = metrics.precision_recall_curve(y_test, y_prob[:,1])
    auc_rc_list.append(metrics.auc(rc, pr))
# Out:
# C:\Users\paula\Anaconda3\envs\evasao\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fig = plt.figure(figsize=(18,10))
for i in range(len(cm_list)):
    cm = cm_list[i]
    model = model_list[i]
    sub = fig.add_subplot(2,3,i+1).set_title(model)
    cm_plot = sns.heatmap(cm, annot=True, cmap="Reds", fmt="d")
    cm_plot.set_ylabel("Actual Value")
    cm_plot.set_xlabel("Predicted Values")

# %%
results_df = pd.DataFrame({"Model": model_list,
                          "Accuracy": acc_list,
                          "AUC": auc_list,"AUC_PR": auc_rc_list})
results_df.sort_values("Accuracy", ascending=False)
# Out:
#                  Model  Accuracy   AUC    AUC_PR
# 4        Random Forest  0.862121  0.86  0.941019
# 3        Decision Tree  0.856406  0.86  0.927516
# 2                  KNN  0.809674  0.81  0.895471
# 1                  SVM  0.739336  0.74  0.787446
# 0  Logistic Regression  0.642280  0.64  0.694977
# 5          Naive Bayes  0.607846  0.61  0.651006

# %% [markdown]
# ### Random Forest

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_test)

# %%
def criar_preds(y_pred):
    df_pred = pd.DataFrame(y_pred)
    df_pred["evadido"] = y_test.values
    return df_pred

def plotar_preds(df_pred, x=0.5):
    plt.hist(df_pred.loc[df_pred.evadido==0][0], bins=30)
    plt.title("Prob de ser 0")
    plt.xlabel("Probabilidade do modelo")
    plt.ylabel("alunos não evadidos")
    plt.show()
    plt.hist(df_pred.loc[df_pred.evadido==1][1], bins=30)
    plt.title("Prob de ser 1")
    plt.xlabel("Probabilidade do modelo")
    plt.ylabel("alunos evadidos")
    plt.vlines(x, 0, 100, 'r', '-')
    plt.show()
    
def criar_cm(df_pred, limite=0.2):
    
    df_pred = pd.DataFrame(y_pred)
    df_pred["evadido"] = y_test.values
    df_pred.loc[df_pred[1] > limite, "pred"] = 1
    df_pred.pred.fillna(0, inplace=True)
    df_pred.loc[(df_pred.pred==0) & (df_pred.evadido==0), "res"] = "TN"
    df_pred.loc[(df_pred.pred==0) & (df_pred.evadido==1), "res"] = "FN"
    df_pred.loc[(df_pred.pred==1) & (df_pred.evadido==0), "res"] = "FP"
    df_pred.loc[(df_pred.pred==1) & (df_pred.evadido==1), "res"] = "TP"
    cm = pd.DataFrame(df_pred.groupby("res").count()["pred"]).reset_index()
    
    return cm

def calcular_metricas(cm):
    recall = cm.loc[cm["res"]=="TP"]["pred"].values / (cm.loc[cm["res"]=="TP"]["pred"].values + cm.loc[cm["res"]=="FN"]["pred"].values)
    precision = cm.loc[cm["res"]=="TP"]["pred"].values / (cm.loc[cm["res"]=="TP"]["pred"].values + cm.loc[cm["res"]=="FP"]["pred"].values)
    f1 = (2 * precision * recall) / (precision + recall)
    return recall, precision, f1

# %%
df_pred = criar_preds(y_pred)
plotar_preds(df_pred, x=0.25)
cm = criar_cm(df_pred, limite=0.2)
print(cm)
recall, precision, f1 = calcular_metricas(cm)
print(recall, precision, f1)
# Out:
#   res   pred
# 0  FN    182
# 1  FP   7403
# 2  TN  13259
# 3  TP  20627
# [0.99125378] [0.73589012] [0.84469379]

# %% [markdown]
# ### BalancedRandomForest

# %%
# random forest for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

# define model
#model = RandomForestClassifier(n_estimators=v10, class_weight='balanced_subsample')
model = BalancedRandomForestClassifier(n_estimators=50)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
#
output = cross_validate(model, X, y, cv=cv, scoring = 'roc_auc', return_estimator =True)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.947

# %%
for idx,estimator in enumerate(output['estimator']):
    print("Features sorted by their score for estimator {}:".format(idx))
    feature_importances = pd.DataFrame(estimator.feature_importances_,
                                       index = X.columns,
                                        columns=['importance']).sort_values('importance', ascending=False)
    print(feature_importances)
# Out:
# Features sorted by their score for estimator 0:
#                         importance
# Cod_Raca_4.0              0.034342
# Cod_Renda_Familiar_1.0    0.031734
# Cod_Escolaridade_5.0      0.031508
# Cod_Renda_Familiar_2.0    0.030627
# Sexo_1.0                  0.027810
# ...                            ...
# Cod_Estado_Civil_3.0      0.000523
# Id_TipoCurso_9            0.000522
# bins_CHE_3                0.000368
# Id_TipoCurso_6            0.000258
# bins_idade_0              0.000128
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 1:
#                         importance
# Cod_Raca_4.0              0.033987
# Cod_Renda_Familiar_2.0    0.032051
# Cod_Escolaridade_5.0      0.030694
# Cod_Renda_Familiar_1.0    0.030639
# Id_Eixo_3                 0.030451
# ...                            ...
# Id_TipoCurso_9            0.000528
# Cod_Estado_Civil_3.0      0.000413
# bins_CHE_3                0.000341
# Id_TipoCurso_6            0.000208
# bins_idade_0              0.000117
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 2:
#                         importance
# Cod_Raca_4.0              0.032670
# Cod_Escolaridade_5.0      0.032251
# Cod_Renda_Familiar_2.0    0.032100
# Cod_Renda_Familiar_1.0    0.030684
# Id_Eixo_3                 0.030078
# ...                            ...
# Id_TipoCurso_9            0.000465
# Cod_Estado_Civil_3.0      0.000453
# bins_CHE_3                0.000395
# Id_TipoCurso_6            0.000263
# bins_idade_0              0.000114
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 3:
#                         importance
# bins_CH_3                 0.034591
# Cod_Raca_4.0              0.034279
# Cod_Escolaridade_5.0      0.030868
# Cod_Renda_Familiar_2.0    0.030269
# Cod_Renda_Familiar_1.0    0.030105
# ...                            ...
# Cod_Estado_Civil_3.0      0.000445
# Id_TipoCurso_9            0.000423
# bins_CHE_3                0.000325
# Id_TipoCurso_6            0.000220
# bins_idade_0              0.000117
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 4:
#                         importance
# Cod_Raca_4.0              0.033707
# Cod_Renda_Familiar_2.0    0.032095
# Cod_Renda_Familiar_1.0    0.031896
# Cod_Escolaridade_5.0      0.031608
# Id_Eixo_3                 0.030784
# ...                            ...
# Id_TipoCurso_9            0.000518
# Cod_Estado_Civil_3.0      0.000486
# bins_CHE_3                0.000414
# Id_TipoCurso_6            0.000197
# bins_idade_0              0.000118
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 5:
#                         importance
# Cod_Raca_4.0              0.034115
# Cod_Renda_Familiar_2.0    0.031486
# Id_Eixo_3                 0.030546
# Cod_Renda_Familiar_1.0    0.030151
# Cod_Escolaridade_5.0      0.030000
# ...                            ...
# Id_TipoCurso_9            0.000451
# Cod_Estado_Civil_3.0      0.000405
# bins_CHE_3                0.000356
# Id_TipoCurso_6            0.000314
# bins_idade_0              0.000127
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 6:
#                         importance
# Cod_Raca_4.0              0.035164
# bins_CH_3                 0.033787
# Cod_Renda_Familiar_2.0    0.031803
# Cod_Renda_Familiar_1.0    0.031726
# Cod_Escolaridade_5.0      0.030850
# ...                            ...
# Cod_Estado_Civil_3.0      0.000415
# Id_TipoCurso_9            0.000409
# bins_CHE_3                0.000391
# Id_TipoCurso_6            0.000201
# bins_idade_0              0.000122
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 7:
#                         importance
# Cod_Raca_4.0              0.032298
# Cod_Renda_Familiar_2.0    0.031857
# Cod_Renda_Familiar_1.0    0.031159
# Id_Eixo_3                 0.030159
# Cod_Escolaridade_5.0      0.029882
# ...                            ...
# Id_TipoCurso_9            0.000519
# Cod_Estado_Civil_3.0      0.000431
# bins_CHE_3                0.000323
# Id_TipoCurso_6            0.000186
# bins_idade_0              0.000121
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 8:
#                         importance
# Cod_Raca_4.0              0.033871
# bins_CH_3                 0.032783
# Cod_Renda_Familiar_2.0    0.030585
# Cod_Escolaridade_5.0      0.030431
# Cod_Escolaridade_4.0      0.029614
# ...                            ...
# Id_TipoCurso_9            0.000447
# Cod_Estado_Civil_3.0      0.000442
# bins_CHE_3                0.000366
# Id_TipoCurso_6            0.000193
# bins_idade_0              0.000143
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 9:
#                         importance
# Cod_Raca_4.0              0.032608
# Cod_Renda_Familiar_2.0    0.032027
# Cod_Renda_Familiar_1.0    0.030758
# Id_Eixo_3                 0.030378
# Cod_Escolaridade_5.0      0.028440
# ...                            ...
# Id_TipoCurso_9            0.000552
# Cod_Estado_Civil_3.0      0.000405
# bins_CHE_3                0.000337
# Id_TipoCurso_6            0.000179
# bins_idade_0              0.000127
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 10:
#                         importance
# Cod_Raca_4.0              0.033943
# Cod_Renda_Familiar_2.0    0.031459
# Cod_Escolaridade_5.0      0.031322
# Cod_Renda_Familiar_1.0    0.030657
# Id_Eixo_3                 0.028874
# ...                            ...
# Cod_Estado_Civil_3.0      0.000534
# Id_TipoCurso_9            0.000513
# bins_CHE_3                0.000301
# Id_TipoCurso_6            0.000258
# bins_idade_0              0.000109
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 11:
#                         importance
# Cod_Raca_4.0              0.034390
# Cod_Escolaridade_5.0      0.031902
# Cod_Renda_Familiar_2.0    0.031533
# Cod_Renda_Familiar_1.0    0.030993
# Id_Eixo_3                 0.029530
# ...                            ...
# Id_TipoCurso_9            0.000501
# Cod_Estado_Civil_3.0      0.000454
# bins_CHE_3                0.000338
# Id_TipoCurso_6            0.000188
# bins_idade_0              0.000121
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 12:
#                         importance
# Cod_Raca_4.0              0.033910
# Cod_Renda_Familiar_2.0    0.030881
# Cod_Renda_Familiar_1.0    0.030479
# Cod_Escolaridade_5.0      0.029492
# Id_Eixo_3                 0.028858
# ...                            ...
# Id_TipoCurso_9            0.000472
# Cod_Estado_Civil_3.0      0.000338
# bins_CHE_3                0.000305
# Id_TipoCurso_6            0.000178
# bins_idade_0              0.000160
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 13:
#                         importance
# Cod_Raca_4.0              0.034157
# Cod_Renda_Familiar_2.0    0.032055
# Cod_Escolaridade_5.0      0.031570
# Cod_Renda_Familiar_1.0    0.029876
# Id_Eixo_3                 0.029255
# ...                            ...
# Id_TipoCurso_9            0.000490
# Cod_Estado_Civil_3.0      0.000456
# bins_CHE_3                0.000339
# Id_TipoCurso_6            0.000291
# bins_idade_0              0.000135
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 14:
#                         importance
# Cod_Raca_4.0              0.033550
# Cod_Renda_Familiar_2.0    0.031864
# Cod_Escolaridade_5.0      0.031768
# Id_Eixo_3                 0.031648
# Cod_Renda_Familiar_1.0    0.030410
# ...                            ...
# Id_TipoCurso_9            0.000441
# Cod_Estado_Civil_3.0      0.000381
# bins_CHE_3                0.000358
# Id_TipoCurso_6            0.000193
# bins_idade_0              0.000134
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 15:
#                         importance
# Cod_Raca_4.0              0.033195
# Cod_Renda_Familiar_2.0    0.032309
# Cod_Renda_Familiar_1.0    0.030989
# Id_Eixo_3                 0.029918
# Cod_Escolaridade_5.0      0.029820
# ...                            ...
# Id_TipoCurso_9            0.000535
# Cod_Estado_Civil_3.0      0.000451
# bins_CHE_3                0.000345
# Id_TipoCurso_6            0.000214
# bins_idade_0              0.000150
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 16:
#                         importance
# Cod_Raca_4.0              0.035124
# Cod_Escolaridade_5.0      0.031949
# Cod_Renda_Familiar_2.0    0.031381
# Cod_Renda_Familiar_1.0    0.031085
# Id_Eixo_3                 0.028900
# ...                            ...
# Id_TipoCurso_9            0.000490
# Cod_Estado_Civil_3.0      0.000478
# bins_CHE_3                0.000345
# Id_TipoCurso_6            0.000216
# bins_idade_0              0.000157
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 17:
#                         importance
# Cod_Raca_4.0              0.033036
# bins_CH_3                 0.032417
# Cod_Renda_Familiar_2.0    0.031068
# Cod_Renda_Familiar_1.0    0.030309
# Cod_Escolaridade_5.0      0.030272
# ...                            ...
# Id_TipoCurso_9            0.000482
# Cod_Estado_Civil_3.0      0.000434
# bins_CHE_3                0.000318
# Id_TipoCurso_6            0.000189
# bins_idade_0              0.000119
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 18:
#                         importance
# Cod_Raca_4.0              0.034178
# Cod_Renda_Familiar_2.0    0.032599
# Cod_Escolaridade_5.0      0.031108
# Id_Eixo_3                 0.030872
# Cod_Renda_Familiar_1.0    0.030775
# ...                            ...
# Id_TipoCurso_9            0.000500
# Cod_Estado_Civil_3.0      0.000430
# bins_CHE_3                0.000374
# Id_TipoCurso_6            0.000186
# bins_idade_0              0.000104
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 19:
#                         importance
# Cod_Raca_4.0              0.034243
# Cod_Renda_Familiar_2.0    0.032467
# bins_CH_3                 0.031722
# Cod_Escolaridade_5.0      0.030602
# Cod_Renda_Familiar_1.0    0.030278
# ...                            ...
# Cod_Estado_Civil_3.0      0.000478
# Id_TipoCurso_9            0.000462
# bins_CHE_3                0.000421
# Id_TipoCurso_6            0.000177
# bins_idade_0              0.000127
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 20:
#                         importance
# Cod_Raca_4.0              0.033817
# Cod_Renda_Familiar_2.0    0.032529
# Cod_Renda_Familiar_1.0    0.032000
# Cod_Escolaridade_5.0      0.030858
# Id_Eixo_3                 0.029520
# ...                            ...
# Id_TipoCurso_9            0.000563
# Cod_Estado_Civil_3.0      0.000416
# bins_CHE_3                0.000352
# Id_TipoCurso_6            0.000182
# bins_idade_0              0.000134
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 21:
#                         importance
# Cod_Raca_4.0              0.034688
# Cod_Renda_Familiar_2.0    0.031429
# Cod_Renda_Familiar_1.0    0.031389
# Id_Eixo_3                 0.029752
# bins_CH_3                 0.029446
# ...                            ...
# Id_TipoCurso_9            0.000498
# bins_CHE_3                0.000414
# Cod_Estado_Civil_3.0      0.000399
# Id_TipoCurso_6            0.000267
# bins_idade_0              0.000136
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 22:
#                         importance
# Cod_Raca_4.0              0.033906
# Cod_Renda_Familiar_2.0    0.032761
# Cod_Escolaridade_5.0      0.031529
# Cod_Renda_Familiar_1.0    0.031476
# Id_Eixo_3                 0.029208
# ...                            ...
# Id_TipoCurso_9            0.000527
# Cod_Estado_Civil_3.0      0.000465
# bins_CHE_3                0.000374
# bins_idade_0              0.000168
# Id_TipoCurso_6            0.000161
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 23:
#                         importance
# Cod_Raca_4.0              0.032800
# Cod_Escolaridade_5.0      0.031954
# Cod_Renda_Familiar_2.0    0.031654
# Cod_Renda_Familiar_1.0    0.030576
# Id_Eixo_3                 0.029417
# ...                            ...
# Id_TipoCurso_9            0.000564
# Cod_Estado_Civil_3.0      0.000461
# bins_CHE_3                0.000400
# Id_TipoCurso_6            0.000198
# bins_idade_0              0.000113
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 24:
#                         importance
# Cod_Raca_4.0              0.032954
# Cod_Renda_Familiar_2.0    0.031937
# Cod_Escolaridade_5.0      0.030640
# bins_idade_2              0.030027
# Cod_Renda_Familiar_1.0    0.029981
# ...                            ...
# Id_TipoCurso_9            0.000511
# Cod_Estado_Civil_3.0      0.000476
# bins_CHE_3                0.000375
# Id_TipoCurso_6            0.000189
# bins_idade_0              0.000132
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 25:
#                         importance
# Cod_Raca_4.0              0.032306
# Cod_Renda_Familiar_2.0    0.031684
# Cod_Escolaridade_5.0      0.031542
# Id_Eixo_3                 0.030568
# Cod_Renda_Familiar_1.0    0.029875
# ...                            ...
# Id_TipoCurso_9            0.000476
# Cod_Estado_Civil_3.0      0.000449
# bins_CHE_3                0.000353
# Id_TipoCurso_6            0.000198
# bins_idade_0              0.000147
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 26:
#                         importance
# Cod_Raca_4.0              0.033647
# Cod_Renda_Familiar_2.0    0.032912
# Cod_Renda_Familiar_1.0    0.031735
# Id_Eixo_3                 0.029556
# Cod_Escolaridade_5.0      0.029353
# ...                            ...
# Id_TipoCurso_9            0.000493
# Cod_Estado_Civil_3.0      0.000457
# bins_CHE_3                0.000335
# Id_TipoCurso_6            0.000225
# bins_idade_0              0.000121
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 27:
#                         importance
# Cod_Raca_4.0              0.033188
# Cod_Renda_Familiar_2.0    0.032575
# Id_Eixo_3                 0.031901
# Cod_Escolaridade_5.0      0.030816
# Cod_Renda_Familiar_1.0    0.029984
# ...                            ...
# Id_TipoCurso_9            0.000625
# Cod_Estado_Civil_3.0      0.000458
# bins_CHE_3                0.000344
# Id_TipoCurso_6            0.000233
# bins_idade_0              0.000141
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 28:
#                         importance
# Cod_Renda_Familiar_2.0    0.033487
# Cod_Raca_4.0              0.032517
# Cod_Renda_Familiar_1.0    0.032030
# Cod_Escolaridade_5.0      0.031842
# bins_CH_3                 0.030648
# ...                            ...
# Id_TipoCurso_9            0.000490
# Cod_Estado_Civil_3.0      0.000447
# bins_CHE_3                0.000331
# Id_TipoCurso_6            0.000172
# bins_idade_0              0.000129
#
# [80 rows x 1 columns]
# Features sorted by their score for estimator 29:
#                         importance
# Cod_Raca_4.0              0.034621
# Cod_Renda_Familiar_2.0    0.032620
# Cod_Renda_Familiar_1.0    0.032211
# Cod_Escolaridade_5.0      0.030682
# Id_Eixo_3                 0.030071
# ...                            ...
# Id_TipoCurso_9            0.000522
# Cod_Estado_Civil_3.0      0.000412
# bins_CHE_3                0.000366
# Id_TipoCurso_6            0.000264
# bins_idade_0              0.000160
#
# [80 rows x 1 columns]

# %%
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_test)

df_pred = criar_preds(y_pred)
plotar_preds(df_pred, 0.5)

cm = criar_cm(df_pred, 0.5)
print(cm)
calcular_metricas(cm)
# Out:
#   res   pred
# 0  FN   2051
# 1  FP   3666
# 2  TN  16996
# 3  TP  18758
# (array([0.90143688]), array([0.83651445]), array([0.86776305]))

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression(class_weight="balanced", solver="liblinear")
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_test)

# %%
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_test)

df_pred = criar_preds(y_pred)
plotar_preds(df_pred, 0.4)

cm = criar_cm(df_pred, 0.4)
print(cm)
calcular_metricas(cm)
# Out:
#   res   pred
# 0  FN   3270
# 1  FP  12047
# 2  TN   8615
# 3  TP  17539
# (array([0.84285646]), array([0.59281417]), array([0.69606112]))

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE
# Resampling the minority class. The strategy can be changed as required.
sm = SMOTE(sampling_strategy='minority', random_state=42)
# Fit the model to generate the data.
oversampled_X, oversampled_Y = sm.fit_sample(_df.drop('evadido', axis=1), _df['evadido'])
oversampled = pd.concat([pd.DataFrame(oversampled_Y), pd.DataFrame(oversampled_X)], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [52], in <cell line: 5>()
#       3 sm = SMOTE(sampling_strategy='minority', random_state=42)
#       4 # Fit the model to generate the data.
# ----> 5 oversampled_X, oversampled_Y = sm.fit_sample(_df.drop('evadido', axis=1), _df['evadido'])
#       6 oversampled = pd.concat([pd.DataFrame(oversampled_Y), pd.DataFrame(oversampled_X)], axis=1)
#
# AttributeError: 'SMOTE' object has no attribute 'fit_sample'
